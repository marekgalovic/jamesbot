# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import json
import nltk
from collections import Counter

# %% [markdown]
# ### Preprocessing

# %%
frames = json.load(open('../data/frames/frames.json'))

# %%
valid_slot_names = {'dst_city': 1, 'or_city': 2, 'str_date': 3, 'n_adults': 4, 'budget': 5}

def parse_turn(turn):
    inform_acts = filter(lambda act: act['name'] == 'inform', turn['labels']['acts'])
    slots = {arg['val']: arg['key'] for act in inform_acts for arg in act['args'] if arg['key'] in valid_slot_names}
    
    return {
        'author': turn['author'],
        'text': turn['text'],
        'slots': slots
    }

parsed_dialogues = list(map(lambda frame: list(map(lambda turn: parse_turn(turn), frame['turns'])), frames))

# %%
def yield_words(dialogues):
    for dialogue in dialogues:
        for turn in dialogue:
            for word in nltk.word_tokenize(turn['text']):
                yield word

word_count = Counter(yield_words(parsed_dialogues))
word_count.most_common(5)
# Out:
# [('.', 11851), ('to', 8492), ('?', 8239), (',', 8047), ('you', 7268)]

# %%
dictionary = {
    '<PAD>': 0,
    '<EOS>': 1,
    '<UNK>': 2,
}
dict_offset = len(dictionary)

for i, (word, _) in enumerate(word_count.most_common()):
    dictionary[word] = i+dict_offset

# %%
def tokenize_slots(slots):
    for (slot_value, slot_name) in slots.items():
        for slot_value_token in nltk.word_tokenize(slot_value):
            yield (slot_value_token, slot_name)

def embed_turn(turn):
    tokens = nltk.word_tokenize(turn['text'])
    tokenized_slots = {value: slot for (value,slot) in tokenize_slots(turn['slots'])}

    return {
        'embedding_ids': [dictionary[token] for token in tokens],
        'slot_ids': [valid_slot_names.get(tokenized_slots.get(token), 0) for token in tokens]
    }
    
embedded = [embed_turn(turn) for dialogue in parsed_dialogues for turn in dialogue]

# %%
with open('../data/processed/frames_dictionary.json', 'w') as dict_file:
    json.dump(dictionary, dict_file)

# %%
with open('../data/processed/neural_slot_filling_v1/slots_dictionary.json', 'w') as dict_file:
    json.dump(valid_slot_names, dict_file)

# %%
with open('../data/processed/neural_slot_filling_v1/parsed_dialogues.json', 'w') as file:
    json.dump(parsed_dialogues, file)

# %%
with open('../data/processed/neural_slot_filling_v1/embedded.json', 'w') as file:
    json.dump(embedded, file)

# %% [markdown]
# ### Load data

# %%
slots = json.load(open('../data/processed/neural_slot_filling_v1/slots_dictionary.json'))
embedded = json.load(open('../data/processed/neural_slot_filling_v1/embedded.json'))
dictionary = json.load(open('../data/processed/frames_dictionary.json'))

# %%
train_size = int(len(embedded)*.8)

train_data = embedded[:train_size]
test_data = embedded[train_size:]

# %%
def pad_sequences(sequences, length):
    result = []
    for sequence in sequences:
        if len(sequence) < length:
            result.append(sequence + [0]*(length - len(sequence)))
        if len(sequence) >= length:
            result.append(sequence[:length])
    return np.array(result)

def samples_iterator(data, batch_size=64, max_len=50):
    for i in range(int(len(data)/batch_size)):
        rows = data[i*batch_size:i*batch_size+batch_size]
        
        token_ids = list(map(lambda x: x['embedding_ids'], rows))
        slot_ids = list(map(lambda x: x['slot_ids'], rows))
        lengths = np.clip(list(map(len, token_ids)), 0, max_len)
        
        max_seq_len = max(lengths)
        
        yield(
            pad_sequences(token_ids, max_seq_len),
            pad_sequences(slot_ids, max_seq_len),
            lengths
        )

# %% [markdown]
# ### Model

# %%
class NSFModel(object):
    
    def __init__(self, tokens, lengths, targets, embeddings_shape=[10000,300], n_slots=5):
        self._tokens = tokens
        self._lengths = lengths
        self._targets = targets
        self._embeddings_shape = embeddings_shape
        self._n_slots = int(n_slots)
        
        self._initialize_embeddings()
        self._initialize_encoder()
        self._output()
        
    def _initialize_embeddings(self):
        with tf.variable_scope('embeddings'):
            self._embeddings = tf.Variable(tf.truncated_normal(self._embeddings_shape, -.3, 3), trainable=True, name='embeddings')
        
        self._tokens_embedded = tf.nn.embedding_lookup(self._embeddings, self._tokens)
        
    def _initialize_encoder(self):
        with tf.variable_scope('encoder'):
            fw_cell, bw_cell = tf.contrib.rnn.GRUCell(300, activation=tf.nn.tanh), tf.contrib.rnn.GRUCell(300, activation=tf.nn.tanh)
            
        outputs, _ = tf.nn.bidirectional_dynamic_rnn(
            fw_cell, bw_cell,
            inputs = self._tokens_embedded,
            sequence_length = self._lengths,
            dtype = tf.float32,
            time_major = True
        )
        
        self._encoder_outputs = tf.concat(outputs, 2)
        
    def _output(self):
        predicted_logits = tf.layers.dense(self._encoder_outputs, self._n_slots)
        targets_onehot = tf.one_hot(self._targets, self._n_slots)
        
        stepwise_ce = tf.nn.softmax_cross_entropy_with_logits(
            labels = targets_onehot,
            logits = predicted_logits
        )
        
        self.predicted = tf.argmax(predicted_logits, 2)
        self.predicted_proba = tf.nn.softmax(predicted_logits)
        
        self.loss = tf.reduce_mean(stepwise_ce)
        self.accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.cast(self._targets, tf.int64), self.predicted), tf.float32))

# %%
graph = tf.Graph()

# %%
with graph.as_default():
    X_tokens = tf.placeholder(tf.int32, [None, None])
    X_len = tf.placeholder(tf.int32, [None])
    y_slots = tf.placeholder(tf.int32, [None, None])
    
    model = NSFModel(X_tokens, X_len, y_slots)
    
    train_op = tf.train.AdamOptimizer().minimize(model.loss)
    
with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    
    for e in range(20):    
        for i, (inputs, targets, lengths) in enumerate(samples_iterator(train_data)):
            fd = {
                X_tokens: inputs.transpose(),
                X_len: lengths,
                y_slots: targets.transpose(),
            }
            _, loss_val, accuracy_val = sess.run([train_op, model.loss, model.accuracy], feed_dict = fd)

            if i % 10 == 0:
                print('Epoch:', e, 'Step:', i, 'Train loss:', loss_val, 'Train accuracy:', accuracy_val)
        
        losses, accuracies = [], []
        for i, (inputs, targets, lengths) in enumerate(samples_iterator(test_data)):
            fd = {
                X_tokens: inputs.transpose(),
                X_len: lengths,
                y_slots: targets.transpose(),
            }
            
            loss_val, accuracy_val = sess.run([model.loss, model.accuracy], feed_dict = fd)
            losses.append(loss_val)
            accuracies.append(accuracy_val)
            
        print('Epoch:', e, 'Test loss:', np.mean(losses), 'Test accuracy:', np.mean(accuracies))
        losses, accuracies = [], []
# Out:
# Epoch: 0 Step: 0 Train loss: 1.72622 Train accuracy: 0.706875
# Epoch: 0 Step: 10 Train loss: 1.1731 Train accuracy: 0.9875
# Epoch: 0 Step: 20 Train loss: 1.1174 Train accuracy: 0.988125
# Epoch: 0 Step: 30 Train loss: 1.1639 Train accuracy: 0.989062
# Epoch: 0 Step: 40 Train loss: 1.13816 Train accuracy: 0.99125
# Epoch: 0 Step: 50 Train loss: 1.12248 Train accuracy: 0.992188
# Epoch: 0 Step: 60 Train loss: 1.07329 Train accuracy: 0.992188
# Epoch: 0 Step: 70 Train loss: 1.12456 Train accuracy: 0.983437
# Epoch: 0 Step: 80 Train loss: 1.13368 Train accuracy: 0.990313
# Epoch: 0 Step: 90 Train loss: 0.927935 Train accuracy: 0.989375
# Epoch: 0 Step: 100 Train loss: 0.985801 Train accuracy: 0.98875
# Epoch: 0 Step: 110 Train loss: 1.07384 Train accuracy: 0.991562
# Epoch: 0 Step: 120 Train loss: 0.901267 Train accuracy: 0.989062
# Epoch: 0 Step: 130 Train loss: 1.04389 Train accuracy: 0.983994
# Epoch: 0 Step: 140 Train loss: 1.12153 Train accuracy: 0.983437
# Epoch: 0 Step: 150 Train loss: 0.974542 Train accuracy: 0.991562
# Epoch: 0 Step: 160 Train loss: 0.972739 Train accuracy: 0.990625
# Epoch: 0 Step: 170 Train loss: 1.01704 Train accuracy: 0.987109
# Epoch: 0 Step: 180 Train loss: 1.02713 Train accuracy: 0.994375
# Epoch: 0 Step: 190 Train loss: 1.0368 Train accuracy: 0.995625
# Epoch: 0 Step: 200 Train loss: 1.01842 Train accuracy: 0.994375
# Epoch: 0 Step: 210 Train loss: 0.935408 Train accuracy: 0.9925
# Epoch: 0 Step: 220 Train loss: 0.952723 Train accuracy: 0.989583
# Epoch: 0 Step: 230 Train loss: 0.890936 Train accuracy: 0.992813
# Epoch: 0 Step: 240 Train loss: 0.965849 Train accuracy: 0.994062
# Epoch: 0 Test loss: 0.888026 Test accuracy: 0.992218
# Epoch: 1 Step: 0 Train loss: 0.852873 Train accuracy: 0.985625
# Epoch: 1 Step: 10 Train loss: 0.892043 Train accuracy: 0.99
# Epoch: 1 Step: 20 Train loss: 0.84461 Train accuracy: 0.991562
# Epoch: 1 Step: 30 Train loss: 0.88582 Train accuracy: 0.993125
# Epoch: 1 Step: 40 Train loss: 0.868622 Train accuracy: 0.9925
# Epoch: 1 Step: 50 Train loss: 0.859417 Train accuracy: 0.994062
# Epoch: 1 Step: 60 Train loss: 0.820725 Train accuracy: 0.99375
# Epoch: 1 Step: 70 Train loss: 0.847002 Train accuracy: 0.990625
# Epoch: 1 Step: 80 Train loss: 0.862765 Train accuracy: 0.992188
# Epoch: 1 Step: 90 Train loss: 0.70379 Train accuracy: 0.991562
# Epoch: 1 Step: 100 Train loss: 0.749519 Train accuracy: 0.991875
# Epoch: 1 Step: 110 Train loss: 0.816584 Train accuracy: 0.993438
# Epoch: 1 Step: 120 Train loss: 0.688116 Train accuracy: 0.992813
# Epoch: 1 Step: 130 Train loss: 0.791159 Train accuracy: 0.988567
# Epoch: 1 Step: 140 Train loss: 0.85136 Train accuracy: 0.989688
# Epoch: 1 Step: 150 Train loss: 0.739942 Train accuracy: 0.994375
# Epoch: 1 Step: 160 Train loss: 0.738618 Train accuracy: 0.99375
# Epoch: 1 Step: 170 Train loss: 0.766278 Train accuracy: 0.992188
# Epoch: 1 Step: 180 Train loss: 0.780679 Train accuracy: 0.99625
# Epoch: 1 Step: 190 Train loss: 0.787463 Train accuracy: 0.99625
# Epoch: 1 Step: 200 Train loss: 0.772903 Train accuracy: 0.995313
# Epoch: 1 Step: 210 Train loss: 0.711009 Train accuracy: 0.992813
# Epoch: 1 Step: 220 Train loss: 0.721495 Train accuracy: 0.993189
# Epoch: 1 Step: 230 Train loss: 0.674357 Train accuracy: 0.995
# Epoch: 1 Step: 240 Train loss: 0.730057 Train accuracy: 0.995938
# Epoch: 1 Test loss: 0.675808 Test accuracy: 0.992865
# Epoch: 2 Step: 0 Train loss: 0.643765 Train accuracy: 0.99125
# Epoch: 2 Step: 10 Train loss: 0.67339 Train accuracy: 0.993125
# Epoch: 2 Step: 20 Train loss: 0.633558 Train accuracy: 0.995313
# Epoch: 2 Step: 30 Train loss: 0.670178 Train accuracy: 0.995938
# Epoch: 2 Step: 40 Train loss: 0.655803 Train accuracy: 0.995313
# Epoch: 2 Step: 50 Train loss: 0.649719 Train accuracy: 0.994375
# Epoch: 2 Step: 60 Train loss: 0.620349 Train accuracy: 0.995313
# Epoch: 2 Step: 70 Train loss: 0.637512 Train accuracy: 0.994687
# Epoch: 2 Step: 80 Train loss: 0.651511 Train accuracy: 0.994375
# Epoch: 2 Step: 90 Train loss: 0.530961 Train accuracy: 0.993125
# Epoch: 2 Step: 100 Train loss: 0.565166 Train accuracy: 0.992813
# Epoch: 2 Step: 110 Train loss: 0.615409 Train accuracy: 0.995625
# Epoch: 2 Step: 120 Train loss: 0.518979 Train accuracy: 0.993438
# Epoch: 2 Step: 130 Train loss: 0.594474 Train accuracy: 0.991997
# Epoch: 2 Step: 140 Train loss: 0.640489 Train accuracy: 0.990937
# Epoch: 2 Step: 150 Train loss: 0.55772 Train accuracy: 0.99625
# Epoch: 2 Step: 160 Train loss: 0.557302 Train accuracy: 0.995625
# Epoch: 2 Step: 170 Train loss: 0.57528 Train accuracy: 0.996094
# Epoch: 2 Step: 180 Train loss: 0.588761 Train accuracy: 0.9975
# Epoch: 2 Step: 190 Train loss: 0.59245 Train accuracy: 0.9975
# Epoch: 2 Step: 200 Train loss: 0.583293 Train accuracy: 0.99625
# Epoch: 2 Step: 210 Train loss: 0.535759 Train accuracy: 0.995
# Epoch: 2 Step: 220 Train loss: 0.543761 Train accuracy: 0.99399
# Epoch: 2 Step: 230 Train loss: 0.508718 Train accuracy: 0.995938
# Epoch: 2 Step: 240 Train loss: 0.549679 Train accuracy: 0.996562
# Epoch: 2 Test loss: 0.514411 Test accuracy: 0.992718
# Epoch: 3 Step: 0 Train loss: 0.485418 Train accuracy: 0.993125
# Epoch: 3 Step: 10 Train loss: 0.508338 Train accuracy: 0.99375
# Epoch: 3 Step: 20 Train loss: 0.477727 Train accuracy: 0.99625
# Epoch: 3 Step: 30 Train loss: 0.504283 Train accuracy: 0.996562
# Epoch: 3 Step: 40 Train loss: 0.494662 Train accuracy: 0.995625
# Epoch: 3 Step: 50 Train loss: 0.48852 Train accuracy: 0.995625
# Epoch: 3 Step: 60 Train loss: 0.467984 Train accuracy: 0.99625
# Epoch: 3 Step: 70 Train loss: 0.48158 Train accuracy: 0.995
# Epoch: 3 Step: 80 Train loss: 0.489741 Train accuracy: 0.99625
# Epoch: 3 Step: 90 Train loss: 0.400602 Train accuracy: 0.994375
# Epoch: 3 Step: 100 Train loss: 0.423967 Train accuracy: 0.995938
# Epoch: 3 Step: 110 Train loss: 0.464349 Train accuracy: 0.996875
# Epoch: 3 Step: 120 Train loss: 0.391261 Train accuracy: 0.994687
# Epoch: 3 Step: 130 Train loss: 0.447288 Train accuracy: 0.992759
# Epoch: 3 Step: 140 Train loss: 0.482954 Train accuracy: 0.991875
# Epoch: 3 Step: 150 Train loss: 0.420837 Train accuracy: 0.995938
# Epoch: 3 Step: 160 Train loss: 0.423069 Train accuracy: 0.995313
# Epoch: 3 Step: 170 Train loss: 0.434248 Train accuracy: 0.996484
# Epoch: 3 Step: 180 Train loss: 0.445267 Train accuracy: 0.997187
# Epoch: 3 Step: 190 Train loss: 0.448089 Train accuracy: 0.997813
# Epoch: 3 Step: 200 Train loss: 0.439852 Train accuracy: 0.9975
# Epoch: 3 Step: 210 Train loss: 0.40446 Train accuracy: 0.995938
# Epoch: 3 Step: 220 Train loss: 0.411478 Train accuracy: 0.994792
# Epoch: 3 Step: 230 Train loss: 0.384492 Train accuracy: 0.9975
# Epoch: 3 Step: 240 Train loss: 0.414896 Train accuracy: 0.996875
# Epoch: 3 Test loss: 0.395801 Test accuracy: 0.992271
# Epoch: 4 Step: 0 Train loss: 0.369438 Train accuracy: 0.993125
# Epoch: 4 Step: 10 Train loss: 0.386315 Train accuracy: 0.994375
# Epoch: 4 Step: 20 Train loss: 0.362008 Train accuracy: 0.996875
# Epoch: 4 Step: 30 Train loss: 0.386912 Train accuracy: 0.994375
# Epoch: 4 Step: 40 Train loss: 0.372984 Train accuracy: 0.9975
# Epoch: 4 Step: 50 Train loss: 0.373319 Train accuracy: 0.996562
# Epoch: 4 Step: 60 Train loss: 0.353886 Train accuracy: 0.9975
# Epoch: 4 Step: 70 Train loss: 0.366696 Train accuracy: 0.995938
# Epoch: 4 Step: 80 Train loss: 0.37346 Train accuracy: 0.995313
# Epoch: 4 Step: 90 Train loss: 0.305676 Train accuracy: 0.994062
# Epoch: 4 Step: 100 Train loss: 0.325392 Train accuracy: 0.995
# Epoch: 4 Step: 110 Train loss: 0.353794 Train accuracy: 0.996562
# Epoch: 4 Step: 120 Train loss: 0.298458 Train accuracy: 0.99375
# Epoch: 4 Step: 130 Train loss: 0.339465 Train accuracy: 0.996189
# Epoch: 4 Step: 140 Train loss: 0.367939 Train accuracy: 0.994687
# Epoch: 4 Step: 150 Train loss: 0.321646 Train accuracy: 0.996562
# Epoch: 4 Step: 160 Train loss: 0.325043 Train accuracy: 0.995625
# Epoch: 4 Step: 170 Train loss: 0.334613 Train accuracy: 0.995313
# Epoch: 4 Step: 180 Train loss: 0.33969 Train accuracy: 0.998125
# Epoch: 4 Step: 190 Train loss: 0.340623 Train accuracy: 0.999062
# Epoch: 4 Step: 200 Train loss: 0.336514 Train accuracy: 0.998125
# Epoch: 4 Step: 210 Train loss: 0.308639 Train accuracy: 0.996562
# Epoch: 4 Step: 220 Train loss: 0.316231 Train accuracy: 0.995593
# Epoch: 4 Step: 230 Train loss: 0.294681 Train accuracy: 0.997187
# Epoch: 4 Step: 240 Train loss: 0.316572 Train accuracy: 0.998125
# Epoch: 4 Test loss: 0.307734 Test accuracy: 0.99284
# Epoch: 5 Step: 0 Train loss: 0.284969 Train accuracy: 0.993125
# Epoch: 5 Step: 10 Train loss: 0.295507 Train accuracy: 0.995938
# Epoch: 5 Step: 20 Train loss: 0.291461 Train accuracy: 0.992813
# Epoch: 5 Step: 30 Train loss: 0.295942 Train accuracy: 0.99625
# Epoch: 5 Step: 40 Train loss: 0.291644 Train accuracy: 0.99625
# Epoch: 5 Step: 50 Train loss: 0.28915 Train accuracy: 0.997187
# Epoch: 5 Step: 60 Train loss: 0.274616 Train accuracy: 0.997187
# Epoch: 5 Step: 70 Train loss: 0.281929 Train accuracy: 0.996562
# Epoch: 5 Step: 80 Train loss: 0.285812 Train accuracy: 0.99625
# Epoch: 5 Step: 90 Train loss: 0.235047 Train accuracy: 0.994062
# Epoch: 5 Step: 100 Train loss: 0.249778 Train accuracy: 0.995938
# Epoch: 5 Step: 110 Train loss: 0.271804 Train accuracy: 0.9975
# Epoch: 5 Step: 120 Train loss: 0.231717 Train accuracy: 0.995
# Epoch: 5 Step: 130 Train loss: 0.26353 Train accuracy: 0.993521
# Epoch: 5 Step: 140 Train loss: 0.284707 Train accuracy: 0.994375
# Epoch: 5 Step: 150 Train loss: 0.248242 Train accuracy: 0.997187
# Epoch: 5 Step: 160 Train loss: 0.25448 Train accuracy: 0.995
# Epoch: 5 Step: 170 Train loss: 0.256118 Train accuracy: 0.996875
# Epoch: 5 Step: 180 Train loss: 0.26335 Train accuracy: 0.997813
# Epoch: 5 Step: 190 Train loss: 0.263564 Train accuracy: 0.99875
# Epoch: 5 Step: 200 Train loss: 0.264854 Train accuracy: 0.996875
# Epoch: 5 Step: 210 Train loss: 0.242023 Train accuracy: 0.995625
# Epoch: 5 Step: 220 Train loss: 0.245484 Train accuracy: 0.995593
# Epoch: 5 Step: 230 Train loss: 0.229746 Train accuracy: 0.996875
# Epoch: 5 Step: 240 Train loss: 0.245951 Train accuracy: 0.99875
# Epoch: 5 Test loss: 0.245263 Test accuracy: 0.993112
# Epoch: 6 Step: 0 Train loss: 0.219463 Train accuracy: 0.994062
# Epoch: 6 Step: 10 Train loss: 0.228824 Train accuracy: 0.99625
# Epoch: 6 Step: 20 Train loss: 0.215107 Train accuracy: 0.997813
# Epoch: 6 Step: 30 Train loss: 0.23115 Train accuracy: 0.996562
# Epoch: 6 Step: 40 Train loss: 0.225005 Train accuracy: 0.996875
# Epoch: 6 Step: 50 Train loss: 0.232954 Train accuracy: 0.994062
# Epoch: 6 Step: 60 Train loss: 0.214438 Train accuracy: 0.99625
# Epoch: 6 Step: 70 Train loss: 0.218246 Train accuracy: 0.997187
# Epoch: 6 Step: 80 Train loss: 0.222404 Train accuracy: 0.996875
# Epoch: 6 Step: 90 Train loss: 0.183551 Train accuracy: 0.994687
# Epoch: 6 Step: 100 Train loss: 0.194614 Train accuracy: 0.996562
# Epoch: 6 Step: 110 Train loss: 0.213157 Train accuracy: 0.997813
# Epoch: 6 Step: 120 Train loss: 0.179199 Train accuracy: 0.995
# Epoch: 6 Step: 130 Train loss: 0.206059 Train accuracy: 0.996189
# Epoch: 6 Step: 140 Train loss: 0.223769 Train accuracy: 0.994687
# Epoch: 6 Step: 150 Train loss: 0.19491 Train accuracy: 0.9975
# Epoch: 6 Step: 160 Train loss: 0.197455 Train accuracy: 0.995938
# Epoch: 6 Step: 170 Train loss: 0.202569 Train accuracy: 0.997266
# Epoch: 6 Step: 180 Train loss: 0.207227 Train accuracy: 0.997813
# Epoch: 6 Step: 190 Train loss: 0.208526 Train accuracy: 0.998438
# Epoch: 6 Step: 200 Train loss: 0.207527 Train accuracy: 0.997187
# Epoch: 6 Step: 210 Train loss: 0.188525 Train accuracy: 0.997187
# Epoch: 6 Step: 220 Train loss: 0.191886 Train accuracy: 0.996795
# Epoch: 6 Step: 230 Train loss: 0.178957 Train accuracy: 0.998438
# Epoch: 6 Step: 240 Train loss: 0.193629 Train accuracy: 0.99875
# Epoch: 6 Test loss: 0.197935 Test accuracy: 0.992934
# Epoch: 7 Step: 0 Train loss: 0.176845 Train accuracy: 0.993438
# Epoch: 7 Step: 10 Train loss: 0.184291 Train accuracy: 0.995
# Epoch: 7 Step: 20 Train loss: 0.170776 Train accuracy: 0.997813
# Epoch: 7 Step: 30 Train loss: 0.182968 Train accuracy: 0.99625
# Epoch: 7 Step: 40 Train loss: 0.176841 Train accuracy: 0.9975
# Epoch: 7 Step: 50 Train loss: 0.174589 Train accuracy: 0.998438
# Epoch: 7 Step: 60 Train loss: 0.167486 Train accuracy: 0.997813
# Epoch: 7 Step: 70 Train loss: 0.181824 Train accuracy: 0.995313
# Epoch: 7 Step: 80 Train loss: 0.17942 Train accuracy: 0.99625
# Epoch: 7 Step: 90 Train loss: 0.146147 Train accuracy: 0.994687
# Epoch: 7 Step: 100 Train loss: 0.15399 Train accuracy: 0.997187
# Epoch: 7 Step: 110 Train loss: 0.171727 Train accuracy: 0.9975
# Epoch: 7 Step: 120 Train loss: 0.142018 Train accuracy: 0.99625
# Epoch: 7 Step: 130 Train loss: 0.164599 Train accuracy: 0.995427
# Epoch: 7 Step: 140 Train loss: 0.179111 Train accuracy: 0.995
# Epoch: 7 Step: 150 Train loss: 0.156686 Train accuracy: 0.996875
# Epoch: 7 Step: 160 Train loss: 0.156876 Train accuracy: 0.996562
# Epoch: 7 Step: 170 Train loss: 0.160719 Train accuracy: 0.998438
# Epoch: 7 Step: 180 Train loss: 0.164863 Train accuracy: 0.997813
# Epoch: 7 Step: 190 Train loss: 0.16576 Train accuracy: 0.998438
# Epoch: 7 Step: 200 Train loss: 0.163672 Train accuracy: 0.997813
# Epoch: 7 Step: 210 Train loss: 0.150722 Train accuracy: 0.997813
# Epoch: 7 Step: 220 Train loss: 0.154992 Train accuracy: 0.995994
# Epoch: 7 Step: 230 Train loss: 0.144387 Train accuracy: 0.998125
# Epoch: 7 Step: 240 Train loss: 0.155734 Train accuracy: 0.998438
# Epoch: 7 Test loss: 0.164609 Test accuracy: 0.992354
# Epoch: 8 Step: 0 Train loss: 0.141377 Train accuracy: 0.995313
# Epoch: 8 Step: 10 Train loss: 0.145292 Train accuracy: 0.99625
# Epoch: 8 Step: 20 Train loss: 0.136208 Train accuracy: 0.99875
# Epoch: 8 Step: 30 Train loss: 0.146422 Train accuracy: 0.996875
# Epoch: 8 Step: 40 Train loss: 0.142678 Train accuracy: 0.997813
# Epoch: 8 Step: 50 Train loss: 0.14205 Train accuracy: 0.998125
# Epoch: 8 Step: 60 Train loss: 0.135359 Train accuracy: 0.998125
# Epoch: 8 Step: 70 Train loss: 0.139081 Train accuracy: 0.997813
# Epoch: 8 Step: 80 Train loss: 0.141787 Train accuracy: 0.996875
# Epoch: 8 Step: 90 Train loss: 0.1203 Train accuracy: 0.994687
# Epoch: 8 Step: 100 Train loss: 0.124152 Train accuracy: 0.997187
# Epoch: 8 Step: 110 Train loss: 0.137735 Train accuracy: 0.998125
# Epoch: 8 Step: 120 Train loss: 0.115062 Train accuracy: 0.995625
# Epoch: 8 Step: 130 Train loss: 0.133336 Train accuracy: 0.995808
# Epoch: 8 Step: 140 Train loss: 0.147184 Train accuracy: 0.994375
# Epoch: 8 Step: 150 Train loss: 0.125194 Train accuracy: 0.997813
# Epoch: 8 Step: 160 Train loss: 0.126741 Train accuracy: 0.997813
# Epoch: 8 Step: 170 Train loss: 0.129186 Train accuracy: 0.999219
# Epoch: 8 Step: 180 Train loss: 0.133826 Train accuracy: 0.998125
# Epoch: 8 Step: 190 Train loss: 0.133287 Train accuracy: 0.999062
# Epoch: 8 Step: 200 Train loss: 0.133757 Train accuracy: 0.997813
# Epoch: 8 Step: 210 Train loss: 0.120952 Train accuracy: 0.998438
# Epoch: 8 Step: 220 Train loss: 0.123121 Train accuracy: 0.997997
# Epoch: 8 Step: 230 Train loss: 0.117026 Train accuracy: 0.998125
# Epoch: 8 Step: 240 Train loss: 0.125301 Train accuracy: 0.99875
# Epoch: 8 Test loss: 0.13954 Test accuracy: 0.993043
# Epoch: 9 Step: 0 Train loss: 0.114549 Train accuracy: 0.995625
# Epoch: 9 Step: 10 Train loss: 0.116257 Train accuracy: 0.997187
# Epoch: 9 Step: 20 Train loss: 0.110475 Train accuracy: 0.99875
# Epoch: 9 Step: 30 Train loss: 0.119011 Train accuracy: 0.997187
# Epoch: 9 Step: 40 Train loss: 0.1176 Train accuracy: 0.996875
# Epoch: 9 Step: 50 Train loss: 0.114028 Train accuracy: 0.999062
# Epoch: 9 Step: 60 Train loss: 0.110255 Train accuracy: 0.998125
# Epoch: 9 Step: 70 Train loss: 0.112504 Train accuracy: 0.998125
# Epoch: 9 Step: 80 Train loss: 0.115196 Train accuracy: 0.997187
# Epoch: 9 Step: 90 Train loss: 0.0965324 Train accuracy: 0.994375
# Epoch: 9 Step: 100 Train loss: 0.101923 Train accuracy: 0.9975
# Epoch: 9 Step: 110 Train loss: 0.113202 Train accuracy: 0.9975
# Epoch: 9 Step: 120 Train loss: 0.0934646 Train accuracy: 0.995938
# Epoch: 9 Step: 130 Train loss: 0.108489 Train accuracy: 0.996189
# Epoch: 9 Step: 140 Train loss: 0.119191 Train accuracy: 0.995625
# Epoch: 9 Step: 150 Train loss: 0.104619 Train accuracy: 0.997187
# Epoch: 9 Step: 160 Train loss: 0.105579 Train accuracy: 0.996875
# Epoch: 9 Step: 170 Train loss: 0.10541 Train accuracy: 0.999219
# Epoch: 9 Step: 180 Train loss: 0.108428 Train accuracy: 0.999375
# Epoch: 9 Step: 190 Train loss: 0.109621 Train accuracy: 0.999062
# Epoch: 9 Step: 200 Train loss: 0.111372 Train accuracy: 0.9975
# Epoch: 9 Step: 210 Train loss: 0.0990639 Train accuracy: 0.999062
# Epoch: 9 Step: 220 Train loss: 0.101195 Train accuracy: 0.997997
# Epoch: 9 Step: 230 Train loss: 0.0957828 Train accuracy: 0.998125
# Epoch: 9 Step: 240 Train loss: 0.102747 Train accuracy: 0.999062
# Epoch: 9 Test loss: 0.12078 Test accuracy: 0.992856
# Epoch: 10 Step: 0 Train loss: 0.0922269 Train accuracy: 0.996562
# Epoch: 10 Step: 10 Train loss: 0.0987303 Train accuracy: 0.995625
# Epoch: 10 Step: 20 Train loss: 0.0923854 Train accuracy: 0.998125
# Epoch: 10 Step: 30 Train loss: 0.0976259 Train accuracy: 0.998438
# Epoch: 10 Step: 40 Train loss: 0.0959812 Train accuracy: 0.9975
# Epoch: 10 Step: 50 Train loss: 0.0939077 Train accuracy: 0.999062
# Epoch: 10 Step: 60 Train loss: 0.0920723 Train accuracy: 0.9975
# Epoch: 10 Step: 70 Train loss: 0.0937127 Train accuracy: 0.998125
# Epoch: 10 Step: 80 Train loss: 0.0954983 Train accuracy: 0.997187
# Epoch: 10 Step: 90 Train loss: 0.0784072 Train accuracy: 0.995938
# Epoch: 10 Step: 100 Train loss: 0.0830069 Train accuracy: 0.997813
# Epoch: 10 Step: 110 Train loss: 0.0909736 Train accuracy: 0.999062
# Epoch: 10 Step: 120 Train loss: 0.0831739 Train accuracy: 0.995313
# Epoch: 10 Step: 130 Train loss: 0.0926526 Train accuracy: 0.994665
# Epoch: 10 Step: 140 Train loss: 0.0997198 Train accuracy: 0.995313
# Epoch: 10 Step: 150 Train loss: 0.0841089 Train accuracy: 0.997813
# Epoch: 10 Step: 160 Train loss: 0.0863375 Train accuracy: 0.997813
# Epoch: 10 Step: 170 Train loss: 0.0882422 Train accuracy: 0.998828
# Epoch: 10 Step: 180 Train loss: 0.0901791 Train accuracy: 0.99875
# Epoch: 10 Step: 190 Train loss: 0.0905303 Train accuracy: 0.999062
# Epoch: 10 Step: 200 Train loss: 0.0910642 Train accuracy: 0.997813
# Epoch: 10 Step: 210 Train loss: 0.0837641 Train accuracy: 0.998125
# Epoch: 10 Step: 220 Train loss: 0.083599 Train accuracy: 0.998397
# Epoch: 10 Step: 230 Train loss: 0.0803919 Train accuracy: 0.998438
# Epoch: 10 Step: 240 Train loss: 0.0855355 Train accuracy: 0.999062
# Epoch: 10 Test loss: 0.103686 Test accuracy: 0.993092
# Epoch: 11 Step: 0 Train loss: 0.0771683 Train accuracy: 0.99625
# Epoch: 11 Step: 10 Train loss: 0.0799412 Train accuracy: 0.9975
# Epoch: 11 Step: 20 Train loss: 0.075519 Train accuracy: 0.99875
# Epoch: 11 Step: 30 Train loss: 0.0825385 Train accuracy: 0.9975
# Epoch: 11 Step: 40 Train loss: 0.0803723 Train accuracy: 0.996875
# Epoch: 11 Step: 50 Train loss: 0.0792983 Train accuracy: 0.99875
# Epoch: 11 Step: 60 Train loss: 0.0747607 Train accuracy: 0.99875
# Epoch: 11 Step: 70 Train loss: 0.078301 Train accuracy: 0.997813
# Epoch: 11 Step: 80 Train loss: 0.0796442 Train accuracy: 0.996875
# Epoch: 11 Step: 90 Train loss: 0.0658695 Train accuracy: 0.995625
# Epoch: 11 Step: 100 Train loss: 0.0706703 Train accuracy: 0.9975
# Epoch: 11 Step: 110 Train loss: 0.0759138 Train accuracy: 0.99875
# Epoch: 11 Step: 120 Train loss: 0.0661205 Train accuracy: 0.996875
# Epoch: 11 Step: 130 Train loss: 0.0743119 Train accuracy: 0.99657
# Epoch: 11 Step: 140 Train loss: 0.0840391 Train accuracy: 0.995625
# Epoch: 11 Step: 150 Train loss: 0.0714839 Train accuracy: 0.997813
# Epoch: 11 Step: 160 Train loss: 0.0788738 Train accuracy: 0.995625
# Epoch: 11 Step: 170 Train loss: 0.0736935 Train accuracy: 0.999219
# Epoch: 11 Step: 180 Train loss: 0.0761001 Train accuracy: 0.998438
# Epoch: 11 Step: 190 Train loss: 0.0754756 Train accuracy: 0.999062
# Epoch: 11 Step: 200 Train loss: 0.0779141 Train accuracy: 0.997813
# Epoch: 11 Step: 210 Train loss: 0.0695931 Train accuracy: 0.997813
# Epoch: 11 Step: 220 Train loss: 0.0725276 Train accuracy: 0.997196
# Epoch: 11 Step: 230 Train loss: 0.0684798 Train accuracy: 0.997813
# Epoch: 11 Step: 240 Train loss: 0.0717832 Train accuracy: 0.999062
# Epoch: 11 Test loss: 0.0921857 Test accuracy: 0.993055
# Epoch: 12 Step: 0 Train loss: 0.066948 Train accuracy: 0.995625
# Epoch: 12 Step: 10 Train loss: 0.0665939 Train accuracy: 0.9975
# Epoch: 12 Step: 20 Train loss: 0.0647975 Train accuracy: 0.997813
# Epoch: 12 Step: 30 Train loss: 0.0706886 Train accuracy: 0.996875
# Epoch: 12 Step: 40 Train loss: 0.0673402 Train accuracy: 0.998125
# Epoch: 12 Step: 50 Train loss: 0.0689558 Train accuracy: 0.998125
# Epoch: 12 Step: 60 Train loss: 0.0626605 Train accuracy: 0.99875
# Epoch: 12 Step: 70 Train loss: 0.0652394 Train accuracy: 0.997813
# Epoch: 12 Step: 80 Train loss: 0.0677342 Train accuracy: 0.996875
# Epoch: 12 Step: 90 Train loss: 0.0555754 Train accuracy: 0.995625
# Epoch: 12 Step: 100 Train loss: 0.0615054 Train accuracy: 0.9975
# Epoch: 12 Step: 110 Train loss: 0.0649292 Train accuracy: 0.998438
# Epoch: 12 Step: 120 Train loss: 0.0570422 Train accuracy: 0.99625
# Epoch: 12 Step: 130 Train loss: 0.0620699 Train accuracy: 0.997332
# Epoch: 12 Step: 140 Train loss: 0.0715529 Train accuracy: 0.994687
# Epoch: 12 Step: 150 Train loss: 0.0609194 Train accuracy: 0.998125
# Epoch: 12 Step: 160 Train loss: 0.0612029 Train accuracy: 0.997813
# Epoch: 12 Step: 170 Train loss: 0.0658688 Train accuracy: 0.997656
# Epoch: 12 Step: 180 Train loss: 0.0647962 Train accuracy: 0.999062
# Epoch: 12 Step: 190 Train loss: 0.0637695 Train accuracy: 0.999062
# Epoch: 12 Step: 200 Train loss: 0.0662924 Train accuracy: 0.9975
# Epoch: 12 Step: 210 Train loss: 0.0589813 Train accuracy: 0.998438
# Epoch: 12 Step: 220 Train loss: 0.0600548 Train accuracy: 0.997596
# Epoch: 12 Step: 230 Train loss: 0.0559001 Train accuracy: 0.99875
# Epoch: 12 Step: 240 Train loss: 0.0606294 Train accuracy: 0.999062
# Epoch: 12 Test loss: 0.0826013 Test accuracy: 0.992883
# Epoch: 13 Step: 0 Train loss: 0.0554636 Train accuracy: 0.99625
# Epoch: 13 Step: 10 Train loss: 0.0564 Train accuracy: 0.9975
# Epoch: 13 Step: 20 Train loss: 0.0540488 Train accuracy: 0.99875
# Epoch: 13 Step: 30 Train loss: 0.0598757 Train accuracy: 0.998125
# Epoch: 13 Step: 40 Train loss: 0.0582797 Train accuracy: 0.997187
# Epoch: 13 Step: 50 Train loss: 0.0564797 Train accuracy: 0.99875
# Epoch: 13 Step: 60 Train loss: 0.0543022 Train accuracy: 0.998125
# Epoch: 13 Step: 70 Train loss: 0.0591208 Train accuracy: 0.996875
# Epoch: 13 Step: 80 Train loss: 0.0556586 Train accuracy: 0.9975
# Epoch: 13 Step: 90 Train loss: 0.0460946 Train accuracy: 0.995938
# Epoch: 13 Step: 100 Train loss: 0.0509615 Train accuracy: 0.9975
# Epoch: 13 Step: 110 Train loss: 0.054958 Train accuracy: 0.998438
# Epoch: 13 Step: 120 Train loss: 0.0475648 Train accuracy: 0.996562
# Epoch: 13 Step: 130 Train loss: 0.054466 Train accuracy: 0.996189
# Epoch: 13 Step: 140 Train loss: 0.0601536 Train accuracy: 0.995625
# Epoch: 13 Step: 150 Train loss: 0.0527353 Train accuracy: 0.998125
# Epoch: 13 Step: 160 Train loss: 0.0525243 Train accuracy: 0.997813
# Epoch: 13 Step: 170 Train loss: 0.0546029 Train accuracy: 0.998047
# Epoch: 13 Step: 180 Train loss: 0.0548527 Train accuracy: 0.999062
# Epoch: 13 Step: 190 Train loss: 0.0546021 Train accuracy: 0.99875
# Epoch: 13 Step: 200 Train loss: 0.0550482 Train accuracy: 0.997813
# Epoch: 13 Step: 210 Train loss: 0.0493863 Train accuracy: 0.99875
# Epoch: 13 Step: 220 Train loss: 0.0504954 Train accuracy: 0.998397
# Epoch: 13 Step: 230 Train loss: 0.0488052 Train accuracy: 0.998438
# Epoch: 13 Step: 240 Train loss: 0.0513192 Train accuracy: 0.999062
# Epoch: 13 Test loss: 0.0743271 Test accuracy: 0.993038
# Epoch: 14 Step: 0 Train loss: 0.047288 Train accuracy: 0.996875
# Epoch: 14 Step: 10 Train loss: 0.0478627 Train accuracy: 0.9975
# Epoch: 14 Step: 20 Train loss: 0.0457386 Train accuracy: 0.99875
# Epoch: 14 Step: 30 Train loss: 0.0496493 Train accuracy: 0.998438
# Epoch: 14 Step: 40 Train loss: 0.0483417 Train accuracy: 0.998125
# Epoch: 14 Step: 50 Train loss: 0.051408 Train accuracy: 0.997813
# Epoch: 14 Step: 60 Train loss: 0.0458115 Train accuracy: 0.998438
# Epoch: 14 Step: 70 Train loss: 0.0482557 Train accuracy: 0.9975
# Epoch: 14 Step: 80 Train loss: 0.04742 Train accuracy: 0.9975
# Epoch: 14 Step: 90 Train loss: 0.0398348 Train accuracy: 0.995313
# Epoch: 14 Step: 100 Train loss: 0.0423354 Train accuracy: 0.998125
# Epoch: 14 Step: 110 Train loss: 0.0468495 Train accuracy: 0.99875
# Epoch: 14 Step: 120 Train loss: 0.041499 Train accuracy: 0.996562
# Epoch: 14 Step: 130 Train loss: 0.0464351 Train accuracy: 0.99657
# Epoch: 14 Step: 140 Train loss: 0.050882 Train accuracy: 0.995938
# Epoch: 14 Step: 150 Train loss: 0.0442087 Train accuracy: 0.997813
# Epoch: 14 Step: 160 Train loss: 0.0438724 Train accuracy: 0.998438
# Epoch: 14 Step: 170 Train loss: 0.0460438 Train accuracy: 0.998438
# Epoch: 14 Step: 180 Train loss: 0.0465606 Train accuracy: 0.999375
# Epoch: 14 Step: 190 Train loss: 0.0460712 Train accuracy: 0.999062
# Epoch: 14 Step: 200 Train loss: 0.0466251 Train accuracy: 0.997813
# Epoch: 14 Step: 210 Train loss: 0.0423866 Train accuracy: 0.999062
# Epoch: 14 Step: 220 Train loss: 0.0431316 Train accuracy: 0.998397
# Epoch: 14 Step: 230 Train loss: 0.0423891 Train accuracy: 0.997813
# Epoch: 14 Step: 240 Train loss: 0.0439039 Train accuracy: 0.999062
# Epoch: 14 Test loss: 0.0688073 Test accuracy: 0.992876
# Epoch: 15 Step: 0 Train loss: 0.0407143 Train accuracy: 0.996562
# Epoch: 15 Step: 10 Train loss: 0.0410732 Train accuracy: 0.997187
# Epoch: 15 Step: 20 Train loss: 0.0397693 Train accuracy: 0.998438
# Epoch: 15 Step: 30 Train loss: 0.0439248 Train accuracy: 0.997813
# Epoch: 15 Step: 40 Train loss: 0.0406921 Train accuracy: 0.998438
# Epoch: 15 Step: 50 Train loss: 0.0417195 Train accuracy: 0.999062
# Epoch: 15 Step: 60 Train loss: 0.0385093 Train accuracy: 0.99875
# Epoch: 15 Step: 70 Train loss: 0.0398674 Train accuracy: 0.998125
# Epoch: 15 Step: 80 Train loss: 0.0408399 Train accuracy: 0.9975
# Epoch: 15 Step: 90 Train loss: 0.0340098 Train accuracy: 0.995313
# Epoch: 15 Step: 100 Train loss: 0.0362017 Train accuracy: 0.998125
# Epoch: 15 Step: 110 Train loss: 0.0401895 Train accuracy: 0.99875
# Epoch: 15 Step: 120 Train loss: 0.0343119 Train accuracy: 0.996562
# Epoch: 15 Step: 130 Train loss: 0.03944 Train accuracy: 0.997713
# Epoch: 15 Step: 140 Train loss: 0.0434692 Train accuracy: 0.995938
# Epoch: 15 Step: 150 Train loss: 0.0382272 Train accuracy: 0.997813
# Epoch: 15 Step: 160 Train loss: 0.0382116 Train accuracy: 0.998125
# Epoch: 15 Step: 170 Train loss: 0.0385112 Train accuracy: 0.998828
# Epoch: 15 Step: 180 Train loss: 0.0394748 Train accuracy: 0.999375
# Epoch: 15 Step: 190 Train loss: 0.0394964 Train accuracy: 0.999062
# Epoch: 15 Step: 200 Train loss: 0.0399565 Train accuracy: 0.998125
# Epoch: 15 Step: 210 Train loss: 0.0362932 Train accuracy: 0.99875
# Epoch: 15 Step: 220 Train loss: 0.0372731 Train accuracy: 0.998397
# Epoch: 15 Step: 230 Train loss: 0.0359708 Train accuracy: 0.99875
# Epoch: 15 Step: 240 Train loss: 0.0393461 Train accuracy: 0.99875
# Epoch: 15 Test loss: 0.0645258 Test accuracy: 0.992933
# Epoch: 16 Step: 0 Train loss: 0.0355932 Train accuracy: 0.996875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-137-d6f4f49d5905> in <module>()
#      18                 y_slots: targets.transpose(),
#      19             }
# ---> 20             _, loss_val, accuracy_val = sess.run([train_op, model.loss, model.accuracy], feed_dict = fd)
#      21
#      22             if i % 10 == 0:
#
# /Users/marekgalovic/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/marekgalovic/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /Users/marekgalovic/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/marekgalovic/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /Users/marekgalovic/.virtualenvs/data/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
def embed_sentence(sentence):
    return np.array([dictionary.get(token, 2) for token in nltk.word_tokenize(sentence)]).reshape(-1, 1)

embedded_sentence = embed_sentence('I am looking for a flight from Dubai to Frankfurt')

print(embedded_sentence.shape)

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    result = sess.run(model.predicted, feed_dict = {
        X_tokens: embedded_sentence,
        X_len: [len(embedded_sentence)]
    })
    
    print(result.reshape(-1))
# Out:
# (10, 1)
# [2 4 1 4 3 4 1 4 1 1]
